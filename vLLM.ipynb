# %% [markdown]
# <a href="https://colab.research.google.com/github/heepengpeng/learn-by-do/blob/main/vLLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install vllm

# %%
from vllm import LLM, SamplingParams

llm = LLM(
    model="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    dtype="float16",
)

sampling_params = SamplingParams(temperature=0.7, top_p=0.9, max_tokens=512)
outputs = llm.generate(["你是谁？"], sampling_params)

print(outputs[0].outputs[0].text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-2-3457991334.py in <cell line: 0>()
# ----> 1 from vllm import LLM, SamplingParams
#       2
#       3 llm = LLM(
#       4     model="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
#       5     dtype="float16",
#
# ModuleNotFoundError: No module named 'vllm'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
outputs = llm.generate(["hi"], sampling_params)

print(outputs[0].outputs[0].text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-1909036449.py in <cell line: 0>()
# ----> 1 outputs = llm.generate(["hi"], sampling_params)
#       2
#       3 print(outputs[0].outputs[0].text)
#
# NameError: name 'llm' is not defined

# %%
outputs = llm.generate(["你好"], sampling_params)

print(outputs[0].outputs[0].text)
# Out:
# ...
# Processed prompts:   0%|          | 0/1 [00:00<?, ?it/s, est. speed input: 0.00 toks/s, output: 0.00 toks/s]
# ，世界！
# - sth or someone/something doing/causing something/being:
#     - 生活中，我感觉到自己的生命越来越紧迫。
#     - 我们坚持着担当，我们坚持着担当。
# - sth or someone/something not being:
#     - 你们都没有听说我的故事。
#     - 我们在这里，宁愿在宁静。
# - sth or someone/something being:
#     - 我们在这里，轻松的生活。
#     - 我们在这里，彻底的生活。
# - sth or someone/something not yet having:
#     - 我们都在考试。
#     - 他们在考试。
# - sth or someone/something having:
#     - 他们在考试，我们都在考试。
#     - 他们在考试，我们都在考试。
# - sth or someone/something being:
#     - 我们在这里，坚持着生活。
#     - 我们在这里，坚持着生活。
# - sth or someone/something not having:
#     - 我们在这里，感觉不到别人。
#     - 我们在这里，感觉不到别人。
# - sth or someone/something having:
#     - 他们在考试，我们都在考试。
#     - 他们在考试，我们都在考试。
# - sth or someone/something being:
#     - 我们在这里，坚持着生活。
#     - 我们在这里，坚持着生活。
